# %%
help()

# %% [markdown]
# TA: Travell agent
#
# TO: Toure Operator
#
# No-Show: Nighter come to Hotel nor cancle the hotel booking

# %% [markdown]
# **hotels:** namr of hotels
# **is_canceled:** if cancled then 1 else 0
# **lead_time:**
# **arrival_date_year:** year of arrival of customer in hote
# **arrival_date_month:** year of arrival of customer in hote
# **arrival_date_week_number:** week number like there are 52 week in a year
# **arrival_date_day_of_month:** date of month
# **stays_in_weekend_nights:** if stayed then 1 else 0
# **stays_in_week_nights:** if stayed then 1 else 0
# **adults:** 1 if yes else 0
# **children:** count of children
# **babies:** cound of babies
# **meal:**
# **country:**
# **market_segment:**
# **distribution_channel:**
# **is_repeated_guest:**
# **previous_cancellations:**
# **previous_bookings_not_canceled:**
# **reserved_room_type:**
# **assigned_room_type:**
# **booking_changes:**
# **deposit_type:**
# **agent:**
# **company:**
# **days_in_waiting_list:**
# **customer_type:**
# **adr:**
# **required_car_parking_spaces:**
# **total_of_special_requests:**
# **reservation_status:**
# **reservation_status_date:**

# %%
for i in hb.columns:
    print(f'**{i}:**\n')
# Out:
# **hotel:**
#
# **is_canceled:**
#
# **lead_time:**
#
# **arrival_date_year:**
#
# **arrival_date_month:**
#
# **arrival_date_week_number:**
#
# **arrival_date_day_of_month:**
#
# **stays_in_weekend_nights:**
#
# **stays_in_week_nights:**
#
# **adults:**
#
# **children:**
#
# **babies:**
#
# **meal:**
#
# **country:**
#
# **market_segment:**
#
# **distribution_channel:**
#
# **is_repeated_guest:**
#
# **previous_cancellations:**
#
# **previous_bookings_not_canceled:**
#
# **reserved_room_type:**
#
# **assigned_room_type:**
#
# **booking_changes:**
#
# **deposit_type:**
#
# **agent:**
#
# **company:**
#
# **days_in_waiting_list:**
#
# **customer_type:**
#
# **adr:**
#
# **required_car_parking_spaces:**
#
# **total_of_special_requests:**
#
# **reservation_status:**
#
# **reservation_status_date:**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data\\hotel_booking.csv')

# %%
#Make a copy of dataset
hb = data.copy()

# %%
hb.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
hb.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hb.shape
# Out:
# (119390, 36)

# %%
hb.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %% [markdown]
# - There are 119390 rows and 36 features in the dataset
# - Features which contains persdonal information **('name', 'email', 'phone-number', 'credit_card')** of customer is importent for analysis, so let's drop those features

# %%
#Drop 'name', 'email', 'phone-number', 'credit_card' columns, because these are customer personal info
hb.drop(['name', 'email','phone-number', 'credit_card'], axis=1, inplace=True)

# %%
hb.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#Check datatype of all features
hb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# - Some features like children and reservation_status_date have wrong datatype, we need to convert them into correct datatype

# %%
#Convert date object into datetime
hb['reservation_status_date'] = pd.to_datetime(hb['reservation_status_date'], format='%Y-%m-%d')

# %%
#Finding numerical and categorical features
num_fea = [fea for fea in hb.columns if hb[fea].dtype!="O"]
cat_fea = [fea for fea in hb.columns if hb[fea].dtype=="O"]

# %%
num_fea
# Out:
# ['is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status_date']

# %%
cat_fea
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status']

# %%
hb.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
#Check the unique values of categorical features
for fea in cat_fea:
    print(f'Unique Values in {fea}: {hb[fea].nunique()}')
    print(hb[fea].unique())
    print('*'*50)
# Out:
# Unique Values in hotel: 2
# ['Resort Hotel' 'City Hotel']
# **************************************************
# Unique Values in arrival_date_month: 12
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# **************************************************
# Unique Values in meal: 5
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# **************************************************
# Unique Values in country: 177
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %%
#Check the unique values of numerical features
for fea in num_fea:
    print(f'Unique Values in {fea}: {hb[fea].nunique()}')
    print(hb[fea].unique())
    print('*'*50)
# Out:
# Unique Values in is_canceled: 2
# [0 1]
# **************************************************
# Unique Values in lead_time: 479
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ### Brief Discription of Features of Dataset

# %% [markdown]
# **hotel:** there are two hotel ['Resort Hotel' 'City Hotel']
#
# **is_canceled:** 0 if cencled else 1
#
# **lead_time:**
#
# **arrival_date_year:** includes 3 years of data [2015 2016 2017]
#
# **arrival_date_month:** records available for all month
#
# **arrival_date_week_number:** there are 53 week of data, **But in an year there are 52 week**, latter we will find it's causes
#
# **arrival_date_day_of_month:**
#
# **NOTE:** So is we required check-in date then we can combine arrival_date_year, arrival_date_month and arrival_date_day_of_month
#
# **stays_in_weekend_nights:**
#
# **stays_in_week_nights:**
#
# **adults:** count of adult, but there are "0" Zero present in this feature
#
# **children:** count of children
#
# **babies:** count of babies
#
# #####################**NOTE:** There are Zero in adult, children, and babies, so **Check for the rows for all three columns having Zero value**
#
# **meal:** there are four type of meal ['BB' 'FB' 'HB' 'SC' 'Undefined'] and there is no meal then mention as Undefined
#
# **country:** Tourist comes from 177 countries
#
# **market_segment:** there are 8 types, Aviation sector coustomer may be there their repete coustomer, because staff of Aviation sector stay in during change over, flight reshedule
#
# **distribution_channel:**
#
# **is_repeated_guest:** if guest is repeted then 1 else 0
#
# **previous_cancellations:**
#
# **previous_bookings_not_canceled:**
#
# **reserved_room_type:** there are 10 types of room for reservation
#
# **assigned_room_type:** there are 12 types of room, which are alloted to customer, i.e in some cases customer may alloted different room then they have been reserved
#
# **booking_changes:**
#
# **deposit_type:** there are 3 types ['No Deposit' 'Refundable' 'Non Refund']
#
# **agent:**
#
# **company:**
#
# **days_in_waiting_list:**
#
# **customer_type:**
#
# **adr:** Agerage daily rate
#
# **required_car_parking_spaces:**
#
# **total_of_special_requests:**
#
# **reservation_status:** there are 3 unique values ['Check-Out' 'Canceled' 'No-Show'], 'No-Show': means customer nighter check-in nor cencled the booking
#
# **reservation_status_date:**

# %% [markdown]
# #### Checking for Missing Values

# %%
#Check For null values
pd.DataFrame({'null_values': hb.isnull().sum(), 'null_value_percent': (hb.isnull().sum()) / (hb.shape[0]) * (100)}).sort_values(by='null_value_percent', ascending=False)
# Out:
#                                 null_values  null_value_percent
# company                              112593           94.306893
# agent                                 16340           13.686238
# country                                 488            0.408744
# children                                  4            0.003350
# arrival_date_month                        0            0.000000
# arrival_date_week_number                  0            0.000000
# hotel                                     0            0.000000
# is_canceled                               0            0.000000
# stays_in_weekend_nights                   0            0.000000
# arrival_date_day_of_month                 0            0.000000
# adults                                    0            0.000000
# stays_in_week_nights                      0            0.000000
# babies                                    0            0.000000
# meal                                      0            0.000000
# ...

# %% [markdown]
# - **company:** Since company featuere have 94% missing values, so let's drop it
# - **agent:** agent have approx 13% of missing values, so either we can fill with 0 or use any other technique to fill null    values or if this feature is not so importent for further analysis, so we can drop this
# - **Children:** children has only 4 null values so we can drop those null values

# %%
#drop company features
hb.drop(['company'], axis=1, inplace=True)

# %%
#Revised Numerical and categorical features
num_fea = [fea for fea in hb.columns if hb[fea].dtype!="O"]
cat_fea = [fea for fea in hb.columns if hb[fea].dtype=="O"]

# %%
hb.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# #### Data Visualizaion

# %%
hb.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
num_cols = 3
num_rows = -(-len(num_fea) // num_cols) 

# plt.figure(figsize=(10, 4))
plt.figure(figsize=(num_cols * 5, num_rows * 4))
for i, fea in enumerate(num_fea, 1):
   
    plt.subplot(num_rows,num_cols ,i)
    sns.histplot(hb[fea], kde=True)
    plt.title(f'Histogram of {fea}')
plt.tight_layout()
plt.show()

# %%
num_cols = 3
num_rows = -(-len(num_fea) // num_cols) 
num_rows
# Out:
# 7

# %%
num_cols = 3
num_rows = len(num_fea) // num_cols +1

asd = hb[hb['adr']<5000]
# plt.figure(figsize=(10, 4))
plt.figure(figsize=(num_cols * 5, num_rows * 4))
for i, fea in enumerate(num_fea, 1):
   
    plt.subplot(num_rows,num_cols ,i)
    sns.histplot(asd[fea], kde=True)
    plt.title(f'Histogram of {fea}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Data Analysis and Data Visualizations

# %%
canclled_perc = hb['is_canceled'].value_counts(normalize=True)
print(canclled_perc)

plt.figure(figsize=(5,4))
plt.title('Reservation Status count')
plt.bar(['Not Canceled', 'Canceled'], hb['is_canceled'].value_counts())
# Out:
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64
# <BarContainer object of 2 artists>

# %% [markdown]
# - There are 37% reservation cancled, which is very high for any business
# - Let's check the booking cancelation for each hotel

# %%
import matplotlib.pyplot as plt

# Assuming 'hb' is your DataFrame and 'is_canceled' is the column of interest

# Calculate value counts and percentages
booking_counts = hb['is_canceled'].value_counts()
percentages = booking_counts / booking_counts.sum() * 100

# Plot the bar chart
plt.figure(figsize=(5, 4))
plt.title('Reservation Status count')
bars = plt.bar(['Not Canceled', 'Canceled'], booking_counts)

# Annotate the bar chart with percentages
for bar, percentage in zip(bars, percentages):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{percentage:.2f}%', ha='center', va='bottom')

plt.ylabel('No. of Reservations')
plt.show()

# %%
#Booking cancilation percentage for each hotel
hb.groupby('hotel')['is_canceled'].count()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: is_canceled, dtype: int64

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x='hotel', hue='is_canceled', data=hb, palette='Blues')
legend_labels,_ = ax.get_legend_handles_labels()
ax.legend(bbox_to_anchor=(1,1))
plt.ylabel('No. of Reservations')
plt.show()
plt.title('Reservation Status in Diff. Hotels', size=12)
plt.xlabel('hotel')
plt.ylabel('No. of Reservations')
plt.legend(['not cancled', 'cancled'])
plt.show()

# %%
#######
THIS CODE DID NOT WORK
#########
# Assuming 'hb' is your DataFrame and 'hotel' and 'is_canceled' are the columns of interest

# Calculate value counts and percentages
counts = hb.groupby(['hotel', 'is_canceled']).size().unstack()
percentages = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot the count plot
plt.figure(figsize=(8, 4))
ax = sns.countplot(x='hotel', hue='is_canceled', data=hb, palette='Blues')

# Annotate the plot with percentages
for p in ax.patches:
    height = p.get_height()
    total = sum([patch.get_height() for patch in ax.patches if patch.get_x() == p.get_x()])
    if total > 0:
        percentage = height / total * 100
        ax.text(p.get_x() + p.get_width() / 2., height + 1, f'{percentage:.2f}%', ha="center")

# Adjust legend and labels
legend_labels,_ = ax.get_legend_handles_labels()
ax.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation Status in Diff. Hotels', size=12)
plt.xlabel('Hotel')
plt.ylabel('No. of Reservations')
plt.legend(['Not Canceled', 'Canceled'], title='Reservation Status')

plt.show()

# %%
resort_hotel = hb[hb['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.722366
# 1    0.277634
# Name: proportion, dtype: float64

# %%
city_hotel = hb[hb['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.58273
# 1    0.41727
# Name: proportion, dtype: float64

# %% [markdown]
# - There are 27.7% cancelation rate in resort hotel and 41.7% cancelation rate in city hotel
# - So City hotel cancelation rate is much higher then Resort hotel

# %% [markdown]
# #### Let's Find the Causes of High Cancelation Rate

# %% [markdown]
# #### adr (average daily rate)

# %%
adr_resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
adr_city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
#line plot to show monthly ADR
plt.figure(figsize=(12,4))
plt.title('Average Daily Rate in City hotel and resort hotel', size=10)
plt.plot(adr_resort_hotel.index, adr_resort_hotel['adr'], label='Resort Hotel')
plt.plot(adr_city_hotel.index, adr_city_hotel['adr'], label='City Hotel')
legend_labels,_ = ax.get_legend_handles_labels()
ax.legend(bbox_to_anchor=(1,1))
plt.legend(['resort_hotel', 'city_hotel'])

# %% [markdown]
# - There are spike, it can be because hotel price will be higher on weekend.
# - we can see that higher then city hotel during 7th to 9th month of each year
# - There are also some spike like 1st month of 2016 for Resort hotel, 2nd or 3rd month of 2016 for City hotel and 1st month of 2017 for resort hotel.

# %% [markdown]
# ##### Let's Find Cancelation of reservation in different momths

# %%
#Extract month from reservation_status_date column
hb['month'] = hb['reservation_status_date'].dt.month

plt.figure(figsize=(12,5))
ax = sns.countplot(x='month', hue='is_canceled', data=hb, palette='Blues')
legend_labels,_ = ax.get_legend_handles_labels()
ax.legend(bbox_to_anchor=(1,1))
plt.title('Reservation Status in diff. month', size=12)
plt.xlabel('hotel')
plt.ylabel('No. of Reservations')
plt.legend(['not cancled', 'cancled'])
plt.show()

# %% [markdown]
# - There is higher cancelation in January and Lowest in August
# - There are Highest Reservation in August and lowest in December and January
# - The Cancelations are gradually reduced from January to June
# - it is little bit confusing that when there is highest reservation in August then there is least cencelation and when there is approx. lowest reservation in January there is highest cencelation.
# - it could be possible that there is low price in August, so there is low cancelation and Higher price in January, so cancelation is High
# - **LET'S PLOT the ADR for each month so, we can find out the causes of cancelation rate**

# %%
monthly_adr = hb[hb['is_canceled']==1].groupby('month')[['adr']].sum().reset_index()
plt.figure(figsize=(8,6))
plt.title('Avg. Daily Rate per Month')
sns.barplot(x='month', y='adr', data = monthly_adr)
# Out:
# <Axes: title={'center': 'Avg. Daily Rate per Month'}, xlabel='month', ylabel='adr'>

# %% [markdown]
# - We can see that There is Highest Average price in January, and also cancelation is also higher in January
# - In August there is the lowest cancelation and there is also average price is approx. lower level
# - **Thus We can conclude that higher the Price highere the cancelation and lower the price lower the cancelation.**

# %% [markdown]
# #### Let's Check Country wise Cancelation

# %%
canceled_hb = hb[hb['is_canceled']==1]
top_country_by_cancelation = canceled_hb['country'].value_counts()[:10]
plt.figure(figsize=(8,6))
plt.title('Tot 10 Countries having most cancelation')
plt.pie(top_country_by_cancelation, autopct = "%.2f%%", labels= top_country_by_cancelation.index)
plt.show()

# %% [markdown]
# - There are 70% cencelation in PRT pourtgal followed by GBR(Great Briten) 6.25% and ESP(Spain) 5.54% of Total Cancelation

# %% [markdown]
# #### Let's Find How the customer make their reservation.
# - Are they comming from Online Travell Agent or offline Travell Agent

# %%
hb['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
hb['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: proportion, dtype: float64

# %% [markdown]
# - 47% customer comes from Online Travell Agent
# - 20% Customer comes from Offline Travell Agent

# %%
hb.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'month'],
#       dtype='object')

# %%
num_cols = 3
num_rows = -(-len(num_fea) // num_cols) 

# plt.figure(figsize=(10, 4))
plt.figure(figsize=(num_cols * 5, num_rows * 4))
for i, fea in enumerate(num_fea, 1):
   
    plt.subplot(num_rows,num_cols ,i)
    sns.histplot(hb[fea], kde=True)
    plt.title(f'Histogram of {fea}')
plt.tight_layout()
plt.show()

# %%
hb['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
hb['market_segment'].value_counts().index
# Out:
# Index(['Online TA', 'Offline TA/TO', 'Groups', 'Direct', 'Corporate',
#        'Complementary', 'Aviation', 'Undefined'],
#       dtype='object', name='market_segment')

# %%
# sns.countplot(x='market_segment', data=hb)
plt.bar(hb['market_segment'].value_counts().index, hb['market_segment'].value_counts())
# Rotate x-axis labels by 60 degrees
plt.xticks(rotation=60)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Online TA'),
#   Text(1, 0, 'Offline TA/TO'),
#   Text(2, 0, 'Groups'),
#   Text(3, 0, 'Direct'),
#   Text(4, 0, 'Corporate'),
#   Text(5, 0, 'Complementary'),
#   Text(6, 0, 'Aviation'),
#   Text(7, 0, 'Undefined')])

# %%
booking_segm_per = hb['market_segment'].value_counts(normalize=True)

# %%
list(hb['market_segment'].unique())
# Out:
# ['Direct',
#  'Corporate',
#  'Online TA',
#  'Offline TA/TO',
#  'Complementary',
#  'Groups',
#  'Undefined',
#  'Aviation']

# %%
import matplotlib.pyplot as plt

unique_item_mark_segm = list(hb['market_segment'].unique())
# Calculate value counts and percentages
booking_segm = hb['market_segment'].value_counts()
booking_segm_per = hb['market_segment'].value_counts(normalize=True) *100
# percentages = booking_counts / booking_counts.sum() * 100

# Plot the bar chart
plt.figure(figsize=(5, 4))
plt.title('Reservation Status count')
bars = plt.bar(unique_item_mark_segm, booking_segm)

# Annotate the bar chart with percentages
for bar, percentage in zip(bars, booking_segm_per):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{percentage:.1f}%', ha='center', va='bottom')

plt.ylabel('No. of Reservations')
# Rotate x-axis labels by 60 degrees
plt.xticks(rotation=60)
plt.show()

# %%
#In Canceled Reservation How much customer make thair reservation with oline TA or ofline TA
canceled_hb['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.468954
# Groups           0.273539
# Offline TA/TO    0.187930
# Direct           0.043732
# Corporate        0.022431
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: proportion, dtype: float64

# %% [markdown]
# - We can see that 47% reservation makes from online TA and out of them approx. 47% reservation also canceled, which is much higher

# %%
#Let's Check the Average Price (adr) for Canceled Reservation and for Not Canceled Reservation 

#Finding Adr for Canceled Reservation
canceled_hb_adr = canceled_hb.groupby('reservation_status_date')[['adr']].mean().reset_index()
canceled_hb_adr.sort_values('reservation_status_date', inplace=True)

#Finding ADR for Not-Canceled Reservation
not_canceled_hb = hb[hb['is_canceled']==0]
not_canceled_hb_adr = not_canceled_hb.groupby('reservation_status_date')[['adr']].mean().reset_index()
not_canceled_hb_adr.sort_values('reservation_status_date', inplace=True)

#Ploting ADR for canceled and not canceled reservation
plt.figure(figsize=(16,6))
plt.title('Average Daily Rate For Canceled and Not-Canceled Reservation')
plt.plot(not_canceled_hb_adr['reservation_status_date'], not_canceled_hb_adr['adr'], label='not cancelled')
plt.plot(canceled_hb_adr['reservation_status_date'], canceled_hb_adr['adr'], label='cancelled')
plt.legend()
plt.show()

# %% [markdown]
# - Here, clearly we can see that Average Daily Price for cancelled Reservation is Higher then that of Not-Cancelled Reservation
# - **Thus one of the causes of reservation cancellation could be Higher Price**

# %%
canceled_hb_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.062779
# 3                2015-01-02    9.633750
# 4                2015-01-18    0.000000
# ..                      ...         ...
# 897              2017-08-26  178.200000
# 898              2017-08-27  167.300000
# 899              2017-08-28   81.416667
# 900              2017-08-29  144.253333
# 901              2017-08-31  189.750000
#
# [902 rows x 2 columns]
